# %% [markdown]
# ## **Prerequisites**
#
# * pip install opencv-python
# * Haar feature-based cascade classifiers xml file ,get <a href="https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml">here</a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
import cv2
import sys

# %%
#Load classifier
face_cascade = cv2.CascadeClassifier('C:/Users/Anwender/Desktop/FaceRecognition/haarcascade_frontalface_default.xml')

CAMERA = cv2.VideoCapture(0)
HEIGHT = 500
RAW_FRAMES = []

while(True):
    # read a new frame
    _, frame = CAMERA.read()


    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    try:
        faces = face_cascade.detectMultiScale(
            gray,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(30, 30),
            flags=cv2.CASCADE_SCALE_IMAGE
            )
    
    except cascade.empty():
        print("your cascade is empty. check file path")
        
    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow('Video', frame)

    # show the frame
    cv2.imshow("Capturing frames", frame)

    key = cv2.waitKey(1)

    # quit camera if 'q' key is pressed
    if key & 0xFF == ord("q"):
        break
    elif key & 0xFF == ord("s"):
        # save the frame
        RAW_FRAMES.append(frame)
        
        # preview the frame
        plt.imshow(frame)
        plt.show()

CAMERA.release()
cv2.destroyAllWindows()

# %%
# show raw frames
for frame in RAW_FRAMES:
    plt.imshow(frame)
    plt.show()
